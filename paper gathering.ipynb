# %%
import pandas as pd
import json
from Bio import Entrez

# %%
# Set the email address to avoid any potential issues with Entrez
Entrez.email = 'rdc47@duke.edu'

# %%
# Define lists of authors and topics
authors = []  # Example authors, adjust as needed
topics = ['RNAi', "siRNA", "ASO", "mRNA"]  # Example topics, adjust as needed

# %%
# Define date range
date_range = '("2020/01/01"[Date - Create] : "2024/09/18"[Date - Create])'

# %%
def parse_pub_date(pub_date): 
    if 'Year' in pub_date: 
        year = pub_date['Year']
        month = pub_date.get('Month', 'Jan')
        day = pub_date.get('Day', '01')
        return f"{year}-{month}-{day}"
    return "Not Available"

# %%
# Build the query dynamically based on the available authors and topics
queries = []

if authors:
    author_queries = ['{}[Author]'.format(author) for author in authors]
    queries.append('(' + ' OR '.join(author_queries) + ')')

if topics:
    topic_queries = ['{}[Title/Abstract]'.format(topic) for topic in topics]
    queries.append('(' + ' OR '.join(topic_queries) + ')')

full_query = ' AND '.join(queries) + ' AND ' + date_range

# %%
# Search PubMed for relevant records
handle = Entrez.esearch(db='pubmed', retmax=100, term=full_query)
record = Entrez.read(handle)
id_list = record['IdList']

# %%
# DataFrame to store the extracted data
df = pd.DataFrame(columns=['PMID', 'Title', 'Abstract', 'Authors', 'Journal', 'Keywords', 'URL', 'Affiliations', "Pub Date"])

# %%
# %%capture
#Fetch information for each record in the id_list
for pmid in id_list:
    handle = Entrez.efetch(db='pubmed', id=pmid, retmode='xml')
    records = Entrez.read(handle)

    # Process each PubMed article in the response
    for record in records['PubmedArticle']:
        # Print the record in a formatted JSON style
        print(json.dumps(record, indent=4, default=str))  # default=str handles types JSON can't serialize like datetime
        title = record['MedlineCitation']['Article']['ArticleTitle']
        abstract = ' '.join(record['MedlineCitation']['Article']['Abstract']['AbstractText']) if 'Abstract' in record['MedlineCitation']['Article'] and 'AbstractText' in record['MedlineCitation']['Article']['Abstract'] else ''
        authors = ', '.join(author.get('LastName', '') + ' ' + author.get('ForeName', '') for author in record['MedlineCitation']['Article']['AuthorList'])
        
        affiliations = []
        for author in record['MedlineCitation']['Article']['AuthorList']:
            if 'AffiliationInfo' in author and author['AffiliationInfo']:
                affiliations.append(author['AffiliationInfo'][0]['Affiliation'])
        affiliations = '; '.join(set(affiliations))

        journal = record['MedlineCitation']['Article']['Journal']['Title']
        keywords = ', '.join(keyword['DescriptorName'] for keyword in record['MedlineCitation']['MeshHeadingList']) if 'MeshHeadingList' in record['MedlineCitation'] else ''
        url = f"https://www.ncbi.nlm.nih.gov/pubmed/{pmid}"
        
        pub_date = parse_pub_date(record['MedlineCitation']['Article']["Journal"]["JournalIssue"]["PubDate"])

        new_row = pd.DataFrame({
            'PMID': [pmid],
            'Title': [title],
            'Abstract': [abstract],
            'Authors': [authors],
            'Journal': [journal],
            'Pub Date': [pub_date],
            'Keywords': [keywords],
            'URL': [url],
            'Affiliations': [affiliations]
        })

        df = pd.concat([df, new_row], ignore_index=True)

# %%
df
# Out:
#         PMID                                              Title  \
# 0   39294861  Anabolic deficits and divergent unfolded prote...
# 1   39294819  Cardioprotective microRNAs (protectomiRs) in a...
# 2   39294751  ZFP64 drives glycolysis-mediated stem cell-lik...
# 3   39294742  Characterization of the angiomodulatory effect...
# 4   39294631  Anti-inflammatory potential of aspergillus ung...
# ..       ...                                                ...
# 95  39288768  Increased Platelet Size and Elevated P2Y12 mRN...
# 96  39288629  Current status of nucleic acid therapy and its...
# 97  39288627  Formononetin ameliorates dextran sulfate sodiu...
# 98  39288626  Activin A inhibits the migration of human lung...
# 99  39288625  SORBS2-Mediated inhibition of malignant behavi...
#
#                                              Abstract  \
# 0   Cancer cachexia manifests as whole body wastin...
# 1   Cardioprotective miRNAs (protectomiRs) are pro...
# 2   Breast cancer (BC) is a great clinical challen...
# 3   The IL-6 cytokine family, with its crucial and...
# 4   Inflammation serves as an intricate defense me...
# ..                                                ...
# 95
# 96  Nucleic acid is an essential biopolymer in all...
# 97  Ulcerative colitis (UC) is a complex, refracto...
# 98  Activin A, a member of the transforming growth...
# 99  Esophageal squamous cell carcinoma (ESCC) is c...
#
#                                               Authors  \
# 0   Belcher Daniel J, Kim Nina, Navarro-Llinas Bla...
# 1   Nagy Regina N, Makkos András, Baranyai Tamás, ...
# 2   Sun Jiayi, Liu Jinquan, Hou Yudong, Bao Jianhe...
# 3   Liang Paula, Ness Jan, Rapp Julian, Boneva Ste...
# 4   Nasr Soad, Dawood Abdelhameed S, Ibrahim Amal ...
# ..                                                ...
# 95  Nishikawa Masako, Nagura Yutaka, Okazaki Hitos...
# 96              Lou Wenting, Zhang Leqi, Wang Jianwei
# 97  Xiao Qiuping, Huang Jiaqi, Zhu Xiyan, Shi Min,...
# 98  Zhang Fenglin, Cui Xueling, Yang Ke, Guo Rui, ...
# 99  Zhang Weiguang, Zhang Peipei, Wang Xiaoqing, L...
#
#                                            Journal  \
# 0                            Physiological reports
# 1                  British journal of pharmacology
# 2                                   Biology direct
# 3                     Journal of neuroinflammation
# 4                                BMC biotechnology
# ..                                             ...
# 95  International journal of laboratory hematology
# 96                International immunopharmacology
# 97                International immunopharmacology
# 98                International immunopharmacology
# 99                International immunopharmacology
#
#                                              Keywords  \
# 0   Animals, Cachexia, Male, Muscle, Skeletal, Rat...
# 1
# 2   Humans, Glycolysis, Breast Neoplasms, Female, ...
# 3   Interleukin-11, Humans, Signal Transduction, A...
# 4   Toll-Like Receptor 4, Mice, Animals, Anti-Infl...
# ..                                                ...
# 95
# 96
# 97
# 98
# 99
#
#                                              URL  \
# 0   https://www.ncbi.nlm.nih.gov/pubmed/39294861
# 1   https://www.ncbi.nlm.nih.gov/pubmed/39294819
# 2   https://www.ncbi.nlm.nih.gov/pubmed/39294751
# 3   https://www.ncbi.nlm.nih.gov/pubmed/39294742
# 4   https://www.ncbi.nlm.nih.gov/pubmed/39294631
# ..                                           ...
# 95  https://www.ncbi.nlm.nih.gov/pubmed/39288768
# 96  https://www.ncbi.nlm.nih.gov/pubmed/39288629
# 97  https://www.ncbi.nlm.nih.gov/pubmed/39288627
# 98  https://www.ncbi.nlm.nih.gov/pubmed/39288626
# 99  https://www.ncbi.nlm.nih.gov/pubmed/39288625
#
#                                          Affiliations     Pub Date
# 0   Department of Biochemistry and Molecular Medic...  2024-Sep-01
# 1   Institute of Physiology, Justus-Liebig Univers...  2024-Sep-18
# 2   Shanxi Datong University, Datong, Shanxi, Peop...  2024-Sep-18
# 3   Eye Center, Medical Center, Faculty of Medicin...  2024-Sep-18
# 4   Drug Bioassay-Cell Culture Laboratory, Pharmac...  2024-Sep-18
# ..                                                ...          ...
# 95  Department of Transfusion Medicine, Graduate S...  2024-Sep-17
# 96  Department of Surgery, The Fourth Affiliated H...  2024-Sep-16
# 97  College of Pharmacy, Jiangxi University of Chi...  2024-Sep-16
# 98  Department of Genetics, College of Basic Medic...  2024-Sep-16
# 99  Department of Thoracic Surgery, Fujian Medical...  2024-Sep-16
#
# [100 rows x 9 columns]

# %%
df.to_excel('PubMed_resultsx.xlsx', index=False)
